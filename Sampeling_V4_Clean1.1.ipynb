# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Sinence-course-Winter-2020/Assignments/blob/master/Sampeling_V4_Clean1.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#V4 _ CLEAN CODE 1.0
import nltk
import random
nltk.download('gutenberg')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.probability import FreqDist
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
set(stopwords.words('english'))
from nltk.tokenize import word_tokenize
import re
import string
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
from random import seed
from random import randint
from random import shuffle
import array
# Out:
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.corpus.gutenberg.fileids()
['austen-emma.txt', 'austen-persuasion.txt', 'austen-sense.txt', 'bible-kjv.txt',
'blake-poems.txt', 'bryant-stories.txt', 'burgess-busterbrown.txt',
'carroll-alice.txt', 'chesterton-ball.txt', 'chesterton-brown.txt',
'chesterton-thursday.txt', 'edgeworth-parents.txt', 'melville-moby_dick.txt',
'milton-paradise.txt', 'shakespeare-caesar.txt', 'shakespeare-hamlet.txt',
'shakespeare-macbeth.txt', 'whitman-leaves.txt']
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
#define 7 books in list
books = [nltk.corpus.gutenberg.raw('austen-emma.txt'), nltk.corpus.gutenberg.raw('bible-kjv.txt'), nltk.corpus.gutenberg.raw('chesterton-ball.txt') , nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt') , nltk.corpus.gutenberg.raw('blake-poems.txt') , nltk.corpus.gutenberg.raw('bryant-stories.txt') , nltk.corpus.gutenberg.raw('whitman-leaves.txt') ]
print ("hi")
#print(books[0])
# Out:
# hi

# %%
#define 7 books   // should be remove after making functional classes
book1 = nltk.corpus.gutenberg.raw('austen-emma.txt')
book2 = nltk.corpus.gutenberg.raw('bible-kjv.txt')
book3 = nltk.corpus.gutenberg.raw('chesterton-ball.txt')
book4 = nltk.corpus.gutenberg.raw('shakespeare-hamlet.txt')
book5 = nltk.corpus.gutenberg.raw('blake-poems.txt')
book6 = nltk.corpus.gutenberg.raw('bryant-stories.txt')
book7 = nltk.corpus.gutenberg.raw('whitman-leaves.txt')

# %%
book = nltk.corpus.gutenberg.raw('chesterton-thursday.txt') #book defination
len(book)
#print (book)
# Out:
# 320525

# %%
#make book lower
def book_lower(i):
  books[i]=books[i].lower()
  print(books[i])

# %%
book_lower(0)
# Out:
# [emma by jane austen 1816]
#
# volume i
#
# chapter i
#
#
# emma woodhouse, handsome, clever, and rich, with a comfortable home
# and happy disposition, seemed to unite some of the best blessings
# of existence; and had lived nearly twenty-one years in the world
# with very little to distress or vex her.
#
# she was the youngest of the two daughters of a most affectionate,
# indulgent father; and had, in consequence of her sister's marriage,
# been mistress of his house from a very early period.  her mother
# had died too long ago for her to have more than an indistinct
# remembrance of her caresses; and her place had been supplied
# by an excellent woman as governess, who had fallen little short
# of a mother in affection.
#
# sixteen years had miss taylor been in mr. woodhouse's family,
# less as a governess than a friend, very fond of both daughters,
# but particularly of emma.  between _them_ it was more the intimacy
# ...

# %%
books[0]
print (books[0])

# %%
#extract words from string without punctuation (FINAL)
res = re.sub('['+string.punctuation+']', '', book).split() 
print (res) #check
print (len(res)) #check
# Out:
# ['the', 'man', 'who', 'was', 'thursday', 'by', 'g', 'k', 'chesterton', '1908', 'to', 'edmund', 'clerihew', 'bentley', 'a', 'cloud', 'was', 'on', 'the', 'mind', 'of', 'men', 'and', 'wailing', 'went', 'the', 'weather', 'yea', 'a', 'sick', 'cloud', 'upon', 'the', 'soul', 'when', 'we', 'were', 'boys', 'together', 'science', 'announced', 'nonentity', 'and', 'art', 'admired', 'decay', 'the', 'world', 'was', 'old', 'and', 'ended', 'but', 'you', 'and', 'i', 'were', 'gay', 'round', 'us', 'in', 'antic', 'order', 'their', 'crippled', 'vices', 'came', 'lust', 'that', 'had', 'lost', 'its', 'laughter', 'fear', 'that', 'had', 'lost', 'its', 'shame', 'like', 'the', 'white', 'lock', 'of', 'whistler', 'that', 'lit', 'our', 'aimless', 'gloom', 'men', 'showed', 'their', 'own', 'white', 'feather', 'as', 'proudly', 'as', 'a', 'plume', 'life', 'was', 'a', 'fly', 'that', 'faded', 'and', 'death', 'a', 'drone', 'that', 'stung', 'the', 'world', 'was', 'very', 'old', 'indeed', 'when', 'you', 'and', 'i', 'were',
# ...

# %%
#removing stop words
tokenized_words = res 
stop_words = stopwords.words('english')
res=[word for word in tokenized_words if word not in stop_words]
print (len(newres))
print (newres)
# Out:
# 28266
# ...

# %%
#Stemmer
ps = PorterStemmer()
example_words = res
new = []
for w in example_words:
  #print(ps.stem(w))
  new.append(ps.stem(w))

res=new
print (res)
len (res)
# Out:
# ['man', 'thursday', 'g', 'k', 'chesterton', '1908', 'edmund', 'clerihew', 'bentley', 'cloud', 'mind', 'men', 'wail', 'went', 'weather', 'yea', 'sick', 'cloud', 'upon', 'soul', 'boy', 'togeth', 'scienc', 'announc', 'nonent', 'art', 'admir', 'decay', 'world', 'old', 'end', 'gay', 'round', 'us', 'antic', 'order', 'crippl', 'vice', 'came', 'lust', 'lost', 'laughter', 'fear', 'lost', 'shame', 'like', 'white', 'lock', 'whistler', 'lit', 'aimless', 'gloom', 'men', 'show', 'white', 'feather', 'proudli', 'plume', 'life', 'fli', 'fade', 'death', 'drone', 'stung', 'world', 'old', 'inde', 'young', 'twist', 'even', 'decent', 'sin', 'shape', 'name', 'men', 'asham', 'honour', 'asham', 'weak', 'foolish', 'thu', 'fail', 'thu', 'black', 'baal', 'block', 'heaven', 'hymn', 'us', 'children', 'wereour', 'fort', 'sand', 'even', 'weak', 'eve', 'high', 'went', 'pile', 'break', 'bitter', 'sea', 'fool', 'motley', 'jangl', 'absurd', 'church', 'bell', 'silent', 'cap', 'bed', 'heard', 'unhelp', 'held', 'fort', 't
# ...

# %%
#number of documents
documentNo=len (res) // 200 #number of words per documents
print (documentNo) #check
# Out:
# 141

# %%
#array for 200 random documentNo + shuffling (FINAL)
value = []
if (documentNo > 150):
  tguess = documentNo - 150

else:
  tguess = documentNo

for _ in range (5): #should be change to 200
  tmp=randint(0,tguess)
  value.append(tmp)
  #print (value)
  
shuffle(value)
print(value)
#print(value[3])
#print(len(value))
# Out:
# [9, 33, 68, 125, 52, 31, 69, 37, 83, 40, 24, 21, 80, 89, 19, 133, 31, 62, 2, 94, 38, 27, 56, 59, 82, 18, 45, 40, 2, 73, 24, 29, 71, 51, 50, 89, 122, 88, 82, 32, 88, 104, 98, 51, 119, 63, 99, 110, 87, 125, 20, 28, 102, 126, 74, 44, 67, 94, 33, 24, 31, 93, 139, 13, 74, 20, 95, 77, 73, 90, 21, 37, 53, 70, 33, 117, 126, 128, 100, 117, 14, 45, 78, 113, 85, 26, 115, 20, 137, 33, 37, 111, 107, 124, 7, 95, 99, 133, 136, 49, 43, 42, 54, 27, 90, 78, 129, 109, 47, 28, 139, 140, 11, 93, 0, 129, 55, 10, 24, 123, 120, 50, 88, 102, 9, 46, 21, 23, 12, 13, 23, 51, 9, 92, 141, 83, 113, 77, 102, 96, 129, 133, 17, 22, 61, 54, 30, 81, 122, 66, 26, 141, 92, 86, 60, 70, 3, 33, 140, 32, 128, 108, 55, 86, 9, 128, 57, 95, 32, 141, 46, 63, 119, 44, 53, 95, 141, 130, 5, 139, 48, 0, 22, 19, 50, 139, 24, 138, 132, 65, 112, 24, 14, 65, 51, 92, 78, 48, 83, 108]

# %%
#array for 200 random documentNo + shuffling (FINAL)
value = []
if (documentNo > 150):
  tguess = documentNo - 150
  for i in range (200): #should be change to 200
    tmp=randint(0,tguess)
    value.append(tmp)
  #print (value)
else:
  tguess = documentNo
  for i in range (200): #should be change to 200
    tmp=randint(0,tguess)
    if (i == 199):  # should be 200 - 1
      print (tmp)
      tmp=tmp-documentNo
    value.append(tmp)
  #print (value)

  
#shuffle(value)
print(value)
#print(value[3])
#print(len(value))
# Out:
# 35
# [13, 54, 1, 70, 3, 99, 45, 94, 24, 97, 78, 34, 86, 118, 37, 101, 107, 76, 39, 93, 60, 41, 107, 29, 52, 87, 97, 7, 21, 93, 99, 134, 23, 0, 136, 64, 96, 18, 60, 110, 138, 91, 47, 71, 114, 52, 67, 136, 86, 20, 6, 52, 62, 16, 95, 33, 32, 8, 86, 113, 61, 57, 62, 6, 12, 79, 24, 55, 74, 2, 60, 87, 120, 125, 91, 74, 80, 37, 29, 115, 88, 103, 66, 36, 43, 69, 47, 105, 121, 56, 49, 109, 58, 32, 41, 129, 30, 67, 11, 42, 53, 34, 55, 14, 74, 71, 74, 116, 68, 79, 60, 59, 130, 26, 68, 78, 110, 82, 11, 102, 58, 106, 8, 88, 86, 96, 11, 131, 18, 41, 24, 14, 114, 53, 140, 38, 76, 113, 59, 48, 112, 40, 137, 97, 16, 0, 10, 69, 78, 34, 74, 22, 10, 65, 18, 29, 54, 88, 115, 88, 27, 103, 78, 104, 104, 39, 61, 111, 34, 127, 78, 95, 86, 119, 68, 129, 27, 59, 81, 41, 124, 67, 95, 129, 106, 82, 86, 5, 95, 50, 111, 22, 60, 75, 62, 136, 50, 95, 95, -106]

# %%
#combine 13 & 6  #Final

i = 0
dataset = []
datasetF = []
listoflists = []
a_list = []

#point = (value[0] * documentNo) + randint(0,tguess)

for i in range (200):  #should be 200 !!
  point = (i * documentNo) + value[i]
  for x in range (150): #should be 150
    dataset.append(res[point])
    point += 1
    #print(dataset) #check each line
    if len(dataset)==150: #should be 150
      datasetF.append((list(dataset)))
      dataset.clear()      

print ("END")
print (datasetF) #the whole dataset for 1 book
len (datasetF)
# Out:
# END
# ...
